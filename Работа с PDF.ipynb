# %%
# %matplotlib inline
from reportlab.pdfgen import canvas
from reportlab.lib import pagesizes
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.lib.utils import ImageReader
from PyPDF2 import PdfMerger, PdfReader
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def extract_district (x):
    return list(map(lambda a: a["District"], x))[0]

r = requests.get("https://video.ittensive.com/python-advanced/data-7361-2019-11-28.utf.json")
data = pd.DataFrame(json.loads(r.content)).fillna(value=0)
data["District"] = data["ObjectAddress"].apply(extract_district)
data_sum = data.groupby("District").sum().sort_values("NumOfVisitors",ascending=False)
fig = plt.figure(figsize=(9,3))
area = fig.add_subplot(1, 1, 1)
data_sum[0:20]["NumOfVisitors"].plot.pie(ax = area,
                                         labels=[""]*20,
                                         label="Посещаемость",
                                         cmap="tab20")
plt.legend(data_sum[0:20].index,
          bbox_to_anchor=(1,1,0.1,0.1))
plt.savefig("readers.png")

pdfmetrics.registerFont(TTFont("Trebuchet", "Trebuchet.ttf"))
PDF = canvas.Canvas("readers.pdf", pagesize=pagesizes.A4)
PDF.setFont("Trebuchet", 48)
PDF.drawString(70, 750, "Посетители библиотек")
PDF.drawString(80, 690, "по районам Москвы")
PDF.setFont("Trebuchet", 13)
PDF.drawString(550, 820, "2")
PDF.drawImage(ImageReader("readers.png"), -300, 300)
PDF.setFont("Trebuchet", 20)
PDF.drawString(100, 150, "Самый популярный район")
PDF.setFont("Trebuchet", 24)
PDF.drawString(100, 120, data_sum.index.to_numpy()[0])
PDF.setFont("Trebuchet", 20)
PDF.drawString(100, 90,"Посетителей: " + str(int(data_sum["NumOfVisitors"].values[0])))
PDF.save()
files = ["title.pdf", "readers.pdf"]
merger = PdfMerger()
for filename in files:
    merger.append(PdfReader(open(filename, "rb")))
merger.write("report.pdf")
# Out:
# C:\Users\makir\AppData\Local\Temp\ipykernel_3692\766006087.py:21: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_sum = data.groupby("District").sum().sort_values("NumOfVisitors",ascending=False)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\users\makir\appdata\local\programs\python\python39\lib\site-packages\reportlab\lib\utils.py:523, in open_for_read.<locals>.open_for_read(name, mode)
#     522 try:
# --> 523     return open_for_read_by_name(name,mode)
#     524 except:
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\site-packages\reportlab\lib\utils.py:463, in open_for_read_by_name(name, mode)
#     462 try:
# --> 463     return open(name,mode)
#     464 except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Trebuchet.ttf'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\users\makir\appdata\local\programs\python\python39\lib\site-packages\reportlab\lib\utils.py:530, in open_for_read.<locals>.open_for_read(name, mode)
#     529             raise ValueError('Attempted untrusted host access')
# --> 530     return BytesIO((datareader if name[:5].lower()=='data:' else rlUrlRead)(name))
#     531 except:
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\site-packages\reportlab\lib\utils.py:476, in rlUrlRead(name)
#     475 def rlUrlRead(name):
# --> 476     return urlopen(name).read()
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\urllib\request.py:501, in OpenerDirector.open(self, fullurl, data, timeout)
#     500 if isinstance(fullurl, str):
# --> 501     req = Request(fullurl, data)
#     502 else:
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\urllib\request.py:320, in Request.__init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     317 def __init__(self, url, data=None, headers={},
#     318              origin_req_host=None, unverifiable=False,
#     319              method=None):
# --> 320     self.full_url = url
#     321     self.headers = {}
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\urllib\request.py:346, in Request.full_url(self, url)
#     345 self._full_url, self.fragment = _splittag(self._full_url)
# --> 346 self._parse()
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\urllib\request.py:375, in Request._parse(self)
#     374 if self.type is None:
# --> 375     raise ValueError("unknown url type: %r" % self.full_url)
#     376 self.host, self.selector = _splithost(rest)
#
# ValueError: unknown url type: 'Trebuchet.ttf'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# File c:\users\makir\appdata\local\programs\python\python39\lib\site-packages\reportlab\pdfbase\ttfonts.py:151, in TTFOpenFile(fn)
#     150 try:
# --> 151     f = open_for_read(fn,'rb')
#     152     return fn, f
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\site-packages\reportlab\lib\utils.py:534, in open_for_read(name, mode)
#     533 globals()['open_for_read'] = open_for_read
# --> 534 return open_for_read(name,mode)
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\site-packages\reportlab\lib\utils.py:532, in open_for_read.<locals>.open_for_read(name, mode)
#     531 except:
# --> 532     raise IOError('Cannot open resource "%s"' % name)
#
# OSError: Cannot open resource "Trebuchet.ttf"
#
# During handling of the above exception, another exception occurred:
#
# TTFError                                  Traceback (most recent call last)
# Cell In [1], line 32
#      28 plt.legend(data_sum[0:20].index,
#      29           bbox_to_anchor=(1,1,0.1,0.1))
#      30 plt.savefig("readers.png")
# ---> 32 pdfmetrics.registerFont(TTFont("Trebuchet", "Trebuchet.ttf"))
#      33 PDF = canvas.Canvas("readers.pdf", pagesize=pagesizes.A4)
#      34 PDF.setFont("Trebuchet", 48)
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\site-packages\reportlab\pdfbase\ttfonts.py:1178, in TTFont.__init__(self, name, filename, validate, subfontIndex, asciiReadable)
#    1172 """Loads a TrueType font from filename.
#    1173
#    1174 If validate is set to a false values, skips checksum validation.  This
#    1175 can save time, especially if the font is large.
#    1176 """
#    1177 self.fontName = name
# -> 1178 self.face = TTFontFace(filename, validate=validate, subfontIndex=subfontIndex)
#    1179 self.encoding = TTEncoding()
#    1180 from weakref import WeakKeyDictionary
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\site-packages\reportlab\pdfbase\ttfonts.py:1072, in TTFontFace.__init__(self, filename, validate, subfontIndex)
#    1070 "Loads a TrueType font from filename."
#    1071 pdfmetrics.TypeFace.__init__(self, None)
# -> 1072 TTFontFile.__init__(self, filename, validate=validate, subfontIndex=subfontIndex)
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\site-packages\reportlab\pdfbase\ttfonts.py:439, in TTFontFile.__init__(self, file, charInfo, validate, subfontIndex)
#     437         self.__dict__.update(__dict__)
#     438 else:
# --> 439     TTFontParser.__init__(self, file, validate=validate,subfontIndex=subfontIndex)
#     440     self.extractInfo(charInfo)
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\site-packages\reportlab\pdfbase\ttfonts.py:175, in TTFontParser.__init__(self, file, validate, subfontIndex)
#     170 """Loads and parses a TrueType font file.  file can be a filename or a
#     171 file object.  If validate is set to a false values, skips checksum
#     172 validation.  This can save time, especially if the font is large.
#     173 """
#     174 self.validate = validate
# --> 175 self.readFile(file)
#     176 isCollection = self.readHeader()
#     177 if isCollection:
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\site-packages\reportlab\pdfbase\ttfonts.py:251, in TTFontParser.readFile(self, f)
#     249     self._ttf_data = f.read()
#     250 else:
# --> 251     self.filename, f = TTFOpenFile(f)
#     252     self._ttf_data = f.read()
#     253     f.close()
#
# File c:\users\makir\appdata\local\programs\python\python39\lib\site-packages\reportlab\pdfbase\ttfonts.py:161, in TTFOpenFile(fn)
#     159             f = open_for_read(tfn,'rb')
#     160             return tfn, f
# --> 161 raise TTFError('Can\'t open file "%s"' % fn)
#
# TTFError: Can't open file "Trebuchet.ttf"
